# %%
class Node(object):
    
    def __init__(self, value):
        
        self.value = value
        self.nextnode = None

# %%
a = Node(1)
b = Node(2)
c = Node(3)

# %%
a.nextNode = b

# %%
b.nextNode = c

# %%
a.value
# Out:
# 1

# %%
a.nextNode

# %%
a.nextNode.value
# Out:
# 2
