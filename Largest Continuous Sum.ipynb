# %%
def large_cont_sum(arr):
    if len(arr) = 0
        return 0
    
    sum = arr[0]
    result = arr[0]
    
    for i in arr[1:]:
        sum = max(sum + i, i)
        result = max(result, sum)
    return result

# %%
large_cont_sum([1, 2, -1, 3, 4, 10, 10, -10, -1])
# Out:
# 29
